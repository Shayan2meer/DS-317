# %% [markdown]
# # Name : Muhammad Shayan

# %% [markdown]
# # Roll No. 211980038

# %% [markdown]
# # Assignment #01

# %%
import pandas as pd
df = pd.read_csv("Dummy_Sales_Data_v1.csv")

# %% [markdown]
# ## df
# This function is used to show all the data in the file.

# %%
df
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## Head:
# This function helps us to get the first 5 rows of the dataset.

# %%
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %% [markdown]
# ## Tail:
# This function will give us the last 5 rows of the dataset.

# %%
df.tail()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9994  2021-10-16             Home         Sofia                  20
# 9995  2021-10-03       Healthcare         Maria                  30
# 9996  2021-11-13           Office          Emma                  29
# 9997  2021-12-23          Fashion        Stella                  22
# 9998  2021-07-12    Entertainment       Anthony                  25
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9994                 14.0            Kenya        H-555     444885
# ...

# %% [markdown]
# ## Sample:
# This function give us the data of randomly selected row and colums.

# %%
df.sample()
# Out:
#                  OrderID  Quantity  UnitPrice(USD)     Status   OrderDate  \
# 123  3899310000999938993        87             168  Delivered  2021-08-11
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 123       Healthcare         Abdul                  26                 24.0
#
#     Shipping_Address Product_Code  OrderCode
# 123          Germany       HC-555     444119

# %% [markdown]
# ## Info:
# This function will give us a quick and important parts of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# ## Describe:
# This function describe the dataset descriptively.

# %%
df.describe()
# Out:
#             OrderID     Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# count  9.999000e+03  9999.000000     9999.000000         9999.000000
# mean   3.020951e+18    50.739874      175.620662           27.571857
# std    1.167549e+18    29.005532       43.527995            4.610452
# min    1.010010e+18     1.000000      100.000000           20.000000
# 25%    2.010410e+18    26.000000      138.000000           24.000000
# 50%    3.002410e+18    51.000000      176.000000           28.000000
# 75%    4.024510e+18    76.000000      213.000000           32.000000
# max    5.049610e+18   100.000000      250.000000           35.000000
#
#        Delivery_Time(Days)      OrderCode
# count          9948.000000    9999.000000
# mean             17.518396  444682.917392
# std               4.609531     525.343171
# min              10.000000  443880.000000
# 25%              14.000000  444222.000000
# 50%              18.000000  444772.000000
# 75%              22.000000  445113.000000
# ...

# %% [markdown]
# ## Loc:
# This function is a property of DataFrame that returns the group of rows and columns
# identified by their labels or names

# %%
#It shows row number 10
df.loc[10]
# Out:
# OrderID                4337210000999943372
# Quantity                                57
# UnitPrice(USD)                         226
# Status                         Not Shipped
# OrderDate                       2021-09-27
# Product_Category                      Home
# Sales_Manager                         John
# Shipping_Cost(USD)                      24
# Delivery_Time(Days)                   14.0
# Shipping_Address                        UK
# Product_Code                         H-555
# OrderCode                           444666
# Name: 10, dtype: object

# %% [markdown]
# ## Query:
# This function give us the anser of our query. This function require one argument about our query.

# %%
df.query("Quantity > 95")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 16    2808810000999928088        96             115      Delivered
# 25    3063710000999930637       100             173  Not Delivered
# 33    3255510000999932555        96             202      Delivered
# 36    4273710000999942737        97             202        Shipped
# 53    1367410000999913674        96             169        Shipped
# ...                   ...       ...             ...            ...
# 9848  3681610000999936816        96             230    Not Shipped
# 9867  3981210000999939812        99             204        Shipped
# 9872  4084910000999940849        98             107    Not Shipped
# 9923  3821010000999938210        98             135  Not Delivered
# 9967  3167110000999931671        99             233      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 16    2021-10-17             Home         Jacob                  30
# ...

# %% [markdown]
# ## Unique:
# This function give us the unqiue value present in the column.

# %%
df["Sales_Manager"].unique()
# Out:
# array(['Pablo', 'Kristen', 'Abdul', 'Stella', 'Emma', 'John', 'Jacob',
#        'Sofia', 'Maria', 'Anthony'], dtype=object)

# %% [markdown]
# #

# %% [markdown]
# # Tasks of Assignment #01

# %% [markdown]
# #

# %% [markdown]
# ## 1).Nunique
#  The nunique () method returns the number of unique values for each column.

# %%
df.nunique()
# Out:
# OrderID                8842
# Quantity                100
# UnitPrice(USD)          151
# Status                    4
# OrderDate               108
# Product_Category          5
# Sales_Manager            10
# Shipping_Cost(USD)       16
# Delivery_Time(Days)      16
# Shipping_Address          8
# Product_Code             30
# OrderCode               108
# dtype: int64

# %% [markdown]
# ## 2).Null:
# This function is used when there is a nul value present in the column or row. If there is No null value, then it returns false.

# %%
df.isnull()
# Out:
#       OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  Product_Category  \
# 0       False     False           False   False      False             False
# 1       False     False           False   False      False             False
# 2       False     False           False   False      False             False
# 3       False     False           False   False      False             False
# 4       False     False           False   False      False             False
# ...       ...       ...             ...     ...        ...               ...
# 9994    False     False           False   False      False             False
# 9995    False     False           False   False      False             False
# 9996    False     False           False   False      False             False
# 9997    False     False           False   False      False             False
# 9998    False     False           False   False      False             False
#
# ...

# %% [markdown]
# ## 3).Fillna:
# This function randomly fills. It require one argument to fill.

# %%
df.fillna(5)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## 4).Sort Values:
# This function is ued to sort the values of the coumns. This function accept two arguments one is the name of the column and other is used for ordering the column.

# %%
df.sort_values("Quantity")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3367  4733210000999947332         1             213    Not Shipped
# 5952  2228310000999922283         1             203  Not Delivered
# 5569  3732610000999937326         1             165        Shipped
# 9516  2719510000999927195         1             247  Not Delivered
# 3429  3276610000999932766         1             157    Not Shipped
# ...                   ...       ...             ...            ...
# 7820  2478510000999924785       100             187      Delivered
# 2739  1262510000999912625       100             101        Shipped
# 551   3442310000999934423       100             218  Not Delivered
# 2719  2829410000999928294       100             117    Not Shipped
# 503   2085610000999920856       100             108  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3367  2021-07-04    Entertainment         Maria                  26
# ...

# %% [markdown]
# ## 5).Count
# This Function is used to require the values present in the coumn. It require one argument which is the name of the column which we want to get the value.

# %%
df.value_counts("Status")
# Out:
# Status
# Not Delivered    2572
# Shipped          2554
# Delivered        2451
# Not Shipped      2422
# dtype: int64

# %% [markdown]
# ## 6).nlargest
# This funnction is used when we are required to get the largest value of present in that row or column. This function accept two values 1st is the row Number and 2nd is the column name.

# %%
df.nlargest(3 , "UnitPrice(USD)")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 22   2111510000999921115        74             250    Delivered  2021-12-08
# 237  4398510000999943985        39             250    Delivered  2021-10-29
# 348  1455310000999914553        93             250  Not Shipped  2021-12-24
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 22        Healthcare         Maria                  25                 21.0
# 237             Home         Pablo                  34                 11.0
# 348       Healthcare          Emma                  25                 17.0
#
#     Shipping_Address Product_Code  OrderCode
# 22             Italy       HC-901     445338
# 237               UK        H-188     444998
# 348            India       HC-555     445554

# %% [markdown]
# ## 7).nSmallest:
# This function is same as nLargest. The difference is that it is used when we need to get the smallest values of the particular column.It requires also two elements. One is number of rows and 2nd is Name of the Colums

# %%
df.nsmallest(5, "UnitPrice(USD)")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 150  4309810000999943098        41             100      Shipped  2021-07-11
# 332  4047410000999940474        89             100    Delivered  2021-07-29
# 536  3635510000999936355        40             100      Shipped  2021-12-26
# 756  1565810000999915658        70             100      Shipped  2021-12-23
# 758  1846210000999918462        84             100  Not Shipped  2021-12-10
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 150             Home         Maria                  26                 22.0
# 332           Office          Emma                  23                 20.0
# 536           Office         Pablo                  29                 21.0
# 756    Entertainment         Sofia                  23                 25.0
# 758          Fashion         Sofia                  28                 13.0
#
#     Shipping_Address Product_Code  OrderCode
# ...

# %% [markdown]
# ## 8).Copy:
# This Function is used to copy the data from one location to other location. There are two typre of copy. One is shallow copy and the other is deep copy.

# %%
s =df.copy()
s
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## 9).Rename:
# This function is used to rename/change the name of the columns. It requires a dictionary on which we store the old and new name of the column which we want to change and then store it in a variable.

# %%
prev = {
        "Status" : "New"    
}

ren = s.rename(columns = prev)
ren
# Out:
#                   OrderID  Quantity  UnitPrice(USD)            New  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ## 10).Where:
# This function will give us a dataframe which have the value according to our given condition. This function require two arguments. One is the name of the column and other is the condition which we want.

# %%
df.where(df["Quantity"] > 70)
# Out:
#            OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0     2.951110e+18      92.0           238.0  Not Delivered  2021-08-08
# 1              NaN       NaN             NaN            NaN         NaN
# 2              NaN       NaN             NaN            NaN         NaN
# 3              NaN       NaN             NaN            NaN         NaN
# 4              NaN       NaN             NaN            NaN         NaN
# ...            ...       ...             ...            ...         ...
# 9994  2.301610e+18      75.0           201.0  Not Delivered  2021-10-16
# 9995           NaN       NaN             NaN            NaN         NaN
# 9996  2.385710e+18      81.0           207.0      Delivered  2021-11-13
# 9997           NaN       NaN             NaN            NaN         NaN
# 9998           NaN       NaN             NaN            NaN         NaN
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %% [markdown]
# ## 11).Corr:
# This function will return a dataframe which has a corelation in the data set.

# %%
df.corr(numeric_only = True)
# Out:
#                       OrderID  Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# OrderID              1.000000  0.008028        0.000866           -0.002899
# Quantity             0.008028  1.000000       -0.007948           -0.008935
# UnitPrice(USD)       0.000866 -0.007948        1.000000           -0.002698
# Shipping_Cost(USD)  -0.002899 -0.008935       -0.002698            1.000000
# Delivery_Time(Days) -0.017483 -0.003023       -0.013938           -0.004026
# OrderCode            0.005441 -0.002827        0.015882            0.008126
#
#                      Delivery_Time(Days)  OrderCode
# OrderID                        -0.017483   0.005441
# Quantity                       -0.003023  -0.002827
# UnitPrice(USD)                 -0.013938   0.015882
# Shipping_Cost(USD)             -0.004026   0.008126
# Delivery_Time(Days)             1.000000   0.008851
# OrderCode                       0.008851   1.000000

# %% [markdown]
# ## 12).Drop:

# %%
df.drop("Status" , axis = "columns")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)   OrderDate  \
# 0     2951110000999929511        92             238  2021-08-08
# 1     2181910000999921819        61             136  2021-10-03
# 2     3239110000999932391        67             235  2021-09-27
# 3     1112610000999911126        33             133  2021-07-30
# 4     1548310000999915483        13             189  2021-08-15
# ...                   ...       ...             ...         ...
# 9994  2301610000999923016        75             201  2021-10-16
# 9995  1847410000999918474        37             135  2021-10-03
# 9996  2385710000999923857        81             207  2021-11-13
# 9997  2281610000999922816        18             117  2021-12-23
# 9998  1468010000999914680        53             229  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0          Healthcare         Pablo                  21                 25.0
# ...

# %% [markdown]
# #                                           End Of Assignment
